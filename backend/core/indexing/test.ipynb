# %%
import requests

api = "KZGRQt4tnEQvqQAvTvrXVPGbnkQj9lBQPBGi2MKCxa8EHZzxuWd%2BdubBeG7SPFPQydjDRwuJuLo6R3A7aIHLAQ%3D%3D"

url = f"http://apis.data.go.kr/1360000/HealthWthrIdxServiceV3/getOakPollenRiskIdxV3?ServiceKey={api}&numOfRows=10&pageNo=1&areaNo=1100000000&time=25042418&dataType=JSON"

# %%
response = requests.get(url)
response.json()
# Out:
# {'response': {'header': {'resultCode': '99',
#    'resultMsg': '해당지수자료 제공기간이 아닙니다! [자료제공기간 4월 ~ 6월]'}}}

# %%
response.text
# Out:
# '<OpenAPI_ServiceResponse>\n\t<cmmMsgHeader>\n\t\t<errMsg>SERVICE ERROR</errMsg>\n\t\t<returnAuthMsg>SERVICE_ACCESS_DENIED_ERROR</returnAuthMsg>\n\t\t<returnReasonCode>20</returnReasonCode>\n\t</cmmMsgHeader>\n</OpenAPI_ServiceResponse>'
